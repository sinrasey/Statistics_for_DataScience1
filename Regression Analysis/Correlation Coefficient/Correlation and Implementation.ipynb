# %% [markdown]
# ## Correlation Coefficient

# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
# df

# %%
x = np.array([1, 2,3, 4, 5.5, 6.6, 7, 8])
y = 3*x-3
z = [ -6.4 ,  -9.2 , -12.34 , -16. , -18.5, -24.8, -22.2 , -29.0 ]
k = [5, 2, 23, 50, 4, 2, 1, 45]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.scatterplot(x= x, y =y, label = 'positive correlation')
sns.regplot(x = x , y = z,color = 'teal',  label = 'Negative Relationship')
plt.show()

# %%
sns.regplot(x= x, y=y)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
# C:\Users\Manon Ya\AppData\Local\Temp\ipykernel_5468\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x
# Out:
# array([1. , 2. , 3. , 4. , 5.5, 6.6, 7. , 8. ])

# %%
df1 = pd.DataFrame({'x':x,
             'y':y,
             'z':z,
              'k':k     })

# %%
df1
# Out:
#      x     y      z   k
# 0  1.0   0.0  -6.40   5
# 1  2.0   3.0  -9.20   2
# 2  3.0   6.0 -12.34  23
# 3  4.0   9.0 -16.00  50
# 4  5.5  13.5 -18.50   4
# 5  6.6  16.8 -24.80   2
# 6  7.0  18.0 -22.20   1
# 7  8.0  21.0 -29.00  45

# %%
df1.corr()
### z :dependent
###, x, y in
# Out:
#           x         y        z         k
# x  1.000000  1.000000 -0.98569  0.188041
# y  1.000000  1.000000 -0.98569  0.188041
# z -0.985690 -0.985690  1.00000 -0.268350
# k  0.188041  0.188041 -0.26835  1.000000

# %%
sns.regplot(x = x, y = k)
# Out:
# <Axes: >

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
a = 1

# %%
a
# Out:
# 1

# %%
df2 = df[['SeniorCitizen', 'gender',  'MonthlyCharges', 'TotalCharges', 'Churn', 'tenure']]

# %%
df2
# Out:
#       SeniorCitizen  gender  MonthlyCharges TotalCharges Churn  tenure
# 0                 0  Female           29.85        29.85    No       1
# 1                 0    Male           56.95       1889.5    No      34
# 2                 0    Male           53.85       108.15   Yes       2
# 3                 0    Male           42.30      1840.75    No      45
# 4                 0  Female           70.70       151.65   Yes       2
# ...             ...     ...             ...          ...   ...     ...
# 7038              0    Male           84.80       1990.5    No      24
# 7039              0  Female          103.20       7362.9    No      72
# 7040              0  Female           29.60       346.45    No      11
# 7041              1    Male           74.40        306.6   Yes       4
# 7042              0    Male          105.65       6844.5    No      66
#
# [7043 rows x 6 columns]

# %%
df2.dtypes
# Out:
# SeniorCitizen       int64
# gender             object
# MonthlyCharges    float64
# TotalCharges       object
# Churn              object
# tenure              int64
# dtype: object

# %%
df2.replace({'Female':1, 'Male':0}, inplace=True)
# Out:
# C:\Users\Manon Ya\AppData\Local\Temp\ipykernel_5468\896671790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.replace({'Female':1, 'Male':0}, inplace=True)

# %% [markdown]
# ## df

# %%
df2.replace({'No':0, 'Yes':1}, inplace=True)
# Out:
# C:\Users\Manon Ya\AppData\Local\Temp\ipykernel_5468\2485850950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.replace({'No':0, 'Yes':1}, inplace=True)

# %%
df2.dtypes
# Out:
# SeniorCitizen       int64
# gender              int64
# MonthlyCharges    float64
# TotalCharges       object
# Churn               int64
# tenure              int64
# dtype: object

# %%
df2['TotalCharges'] = pd.to_numeric(df2['TotalCharges'], errors='coerce')
# Out:
# C:\Users\Manon Ya\AppData\Local\Temp\ipykernel_5468\2934292371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['TotalCharges'] = pd.to_numeric(df2['TotalCharges'], errors='coerce')

# %%
df2['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df2.isnull().sum()
# Out:
# SeniorCitizen      0
# gender             0
# MonthlyCharges     0
# TotalCharges      11
# Churn              0
# tenure             0
# dtype: int64

# %%
df2[df2['TotalCharges'].isnull()].index
# Out:
# Int64Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
df.iloc[[488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], [-2]]
# Out:
#      TotalCharges
# 488
# 753
# 936
# 1082
# 1340
# 3331
# 3826
# 4380
# 5218
# 6670
# 6754

# %%
Totalchange_missing = df.loc[[488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], ['TotalCharges']]

# %%
Totalchange_missing.values
# Out:
# array([[' '],
#        [' '],
#        [' '],
#        [' '],
#        [' '],
#        [' '],
#        [' '],
#        [' '],
#        [' '],
#        [' '],
#        [' ']], dtype=object)

# %%
df2.dropna(inplace=True)
# Out:
# C:\Users\Manon Ya\AppData\Local\Temp\ipykernel_5468\1761232742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)

# %%
df2.corr()
# Out:
#                 SeniorCitizen    gender  MonthlyCharges  TotalCharges  \
# SeniorCitizen        1.000000  0.001819        0.219874      0.102411
# gender               0.001819  1.000000        0.013779     -0.000048
# MonthlyCharges       0.219874  0.013779        1.000000      0.651065
# TotalCharges         0.102411 -0.000048        0.651065      1.000000
# Churn                0.150541  0.008545        0.192858     -0.199484
# tenure               0.015683 -0.005285        0.246862      0.825880
#
#                    Churn    tenure
# SeniorCitizen   0.150541  0.015683
# gender          0.008545 -0.005285
# MonthlyCharges  0.192858  0.246862
# TotalCharges   -0.199484  0.825880
# Churn           1.000000 -0.354049
# tenure         -0.354049  1.000000

# %%
sns.regplot(y=df2['TotalCharges'], x= df['MonthlyCharges'])
plt.show()

# %%
df2.dtypes
# Out:
# SeniorCitizen       int64
# gender              int64
# MonthlyCharges    float64
# TotalCharges      float64
# Churn               int64
# tenure              int64
# dtype: object

# %%
df2.dropna(inplace=True)
# Out:
# C:\Users\Manon Ya\AppData\Local\Temp\ipykernel_5468\1761232742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)

# %%
y = df2['TotalCharges']
x = df2.drop(columns=['TotalCharges'])

# %%
y
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
x
# Out:
#       SeniorCitizen  gender  MonthlyCharges  Churn  tenure
# 0                 0       1           29.85      0       1
# 1                 0       0           56.95      0      34
# 2                 0       0           53.85      1       2
# 3                 0       0           42.30      0      45
# 4                 0       1           70.70      1       2
# ...             ...     ...             ...    ...     ...
# 7038              0       0           84.80      0      24
# 7039              0       1          103.20      0      72
# 7040              0       1           29.60      0      11
# 7041              1       0           74.40      1       4
# 7042              0       0          105.65      0      66
#
# [7032 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df2.shape
# Out:
# (7032, 6)

# %%
a , b = df2.shape

# %%
a
# Out:
# 7032

# %%
1-0.25
# Out:
# 0.75

# %%
x_train , x_test, y_train , y_test = train_test_split(x, y, test_size=0.25)

# %%
y_train
# Out:
# 585       85.70
# 1377    5815.15
# 5737    1611.15
# 3731     146.65
# 3760     232.50
#          ...
# 4273    2404.15
# 4444      63.75
# 6082    6039.90
# 2495     814.75
# 6292    3835.55
# Name: TotalCharges, Length: 5274, dtype: float64

# %%
x_test
# Out:
#       SeniorCitizen  gender  MonthlyCharges  Churn  tenure
# 6492              0       0           19.75      0      24
# 2983              0       0           89.90      0      71
# 6324              0       1           75.85      0       9
# 3819              0       0           30.75      0      46
# 5860              0       1           70.00      1       2
# ...             ...     ...             ...    ...     ...
# 3472              1       1          104.75      0      56
# 643               1       1           89.85      0      49
# 3322              1       1           84.45      1       9
# 3864              0       1          100.20      1      30
# 3993              0       1           66.00      0      70
#
# [1758 rows x 5 columns]

# %%
x_train
# Out:
#       SeniorCitizen  gender  MonthlyCharges  Churn  tenure
# 585               1       1           85.70      1       1
# 1377              0       0           82.30      0      72
# 5737              0       0           83.25      0      18
# 3731              0       0           69.80      0       2
# 3760              0       0           73.60      0       3
# ...             ...     ...             ...    ...     ...
# 4273              0       1           79.85      1      31
# 4444              0       1           19.85      1       3
# 6082              0       1          101.10      1      59
# 2495              0       1           20.25      0      38
# 6292              0       0          100.00      0      39
#
# [5274 rows x 5 columns]

# %%
y_train
# Out:
# 585       85.70
# 1377    5815.15
# 5737    1611.15
# 3731     146.65
# 3760     232.50
#          ...
# 4273    2404.15
# 4444      63.75
# 6082    6039.90
# 2495     814.75
# 6292    3835.55
# Name: TotalCharges, Length: 5274, dtype: float64

# %%
x_train
# Out:
#       SeniorCitizen  gender  MonthlyCharges  Churn  tenure
# 585               1       1           85.70      1       1
# 1377              0       0           82.30      0      72
# 5737              0       0           83.25      0      18
# 3731              0       0           69.80      0       2
# 3760              0       0           73.60      0       3
# ...             ...     ...             ...    ...     ...
# 4273              0       1           79.85      1      31
# 4444              0       1           19.85      1       3
# 6082              0       1          101.10      1      59
# 2495              0       1           20.25      0      38
# 6292              0       0          100.00      0      39
#
# [5274 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
Linear_model = LinearRegression()

# %%
Linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
Linear_model.coef_
# Out:
# array([ -62.45235593,  -16.37912008,   36.98642409, -265.62467821,
#          63.38274309])

# %%
Linear_model.intercept_
# Out:
# -2081.2545556734894

# %%
Linear_model.score(x_train, y_train)
# Out:
# 0.8969248549608737

# %%
Linear_model.score(x_test, y_test)
# Out:
# 0.8978930435333938

# %%
Linear_model.predict(x_test)
# Out:
# array([ 170.4131543 , 5743.99972964, 1278.23127958, ..., 1268.23749265,
#        3244.26363291, 4780.26233062])

# %%
y_test
# Out:
# 6492     483.15
# 2983    6457.15
# 6324     647.50
# 3819    1489.30
# 5860     153.05
#          ...
# 3472    5841.35
# 643     4287.20
# 3322     762.50
# 3864    2983.80
# 3993    4891.50
# Name: TotalCharges, Length: 1758, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, Linear_model.predict(x_test))
# Out:
# 0.8978930435333938

# %%
error = Linear_model.predict(x_test)-y_test

# %%
error
# Out:
# 6492   -312.736846
# 2983   -713.150270
# 6324    630.731280
# 3819    482.384167
# 5860    199.506819
#            ...
# 3472   -577.674495
# 643     -18.301416
# 3322    505.737493
# 3864    260.463633
# 3993   -111.237669
# Name: TotalCharges, Length: 1758, dtype: float64

# %%
Linear_model.predict(x_test)
# Out:
# array([ 170.4131543 , 5743.99972964, 1278.23127958, ..., 1268.23749265,
#        3244.26363291, 4780.26233062])

# %%
y
# Out:
# 6492     483.15
# 2983    6457.15
# 6324     647.50
# 3819    1489.30
# 5860     153.05
#          ...
# 3472    5841.35
# 643     4287.20
# 3322     762.50
# 3864    2983.80
# 3993    4891.50
# Name: TotalCharges, Length: 1758, dtype: float64

# %%
error
# Out:
# 6492   -312.736846
# 2983   -713.150270
# 6324    630.731280
# 3819    482.384167
# 5860    199.506819
#            ...
# 3472   -577.674495
# 643     -18.301416
# 3322    505.737493
# 3864    260.463633
# 3993   -111.237669
# Name: TotalCharges, Length: 1758, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ### Metrics
# The three most common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %%
mean_absolute_error(y_true= y_test, y_pred=Linear_model.predict(x_test))
# Out:
# 587.0757627939345

# %%
np.sqrt(mean_squared_error(y_true= y_test, y_pred=Linear_model.predict(x_test)))
# Out:
# 733.7983652383715

# %%
error.describe()
# Out:
# count    1758.000000
# mean       -7.093139
# std       733.972864
# min     -1868.734019
# 25%      -490.594470
# 50%        95.589764
# 75%       453.835262
# max      1897.332107
# Name: TotalCharges, dtype: float64

# %%
sns.kdeplot(error);

# %%
import statsmodels.api as sm

X_trian_with_cont = sm.add_constant(x_train)
model_liear = sm.OLS(y_train, X_trian_with_cont).fit()

# %%
model_liear

# %%
model_liear.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           TotalCharges   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.897
# Method:                 Least Squares   F-statistic:                     9168.
# Date:                Thu, 11 Jan 2024   Prob (F-statistic):               0.00
# Time:                        16:18:53   Log-Likelihood:                -42215.
# No. Observations:                5274   AIC:                         8.444e+04
# Df Residuals:                    5268   BIC:                         8.448e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...
